# %% [markdown]
# ### Libraries and session

# %%
import pyspark
import boto3
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, TimestampType, IntegerType, DateType, DecimalType
from pyspark.sql.functions import year, to_date, month, dayofmonth,  from_unixtime, unix_timestamp

# %%
# ip and environments
environment = 'prd'

# Source
system_source = "bscs"
system_table ="bscs_mputmtab"

# Set the bucket and folder paths
source_bucket = 'landing-zone'
source_folder = f'database/{system_source}/{system_table}'

lakehouse_bucket = 'lakehouse'
lakehouse_folder = 'iceberg'

# table destination settings
dest_db_catalog = 'iceberg'
dest_db_schema = 'bronze'
dest_db_table = system_table
dest_final_db = f'{dest_db_catalog}.{dest_db_schema}'
dest_final_table = f'{dest_final_db}.{dest_db_table}'

# Spark identification and settings
appname = f'BRONZE_{dest_final_db}.{dest_final_table}'
log_level = 'WARN' # Valid log levels include: ALL, DEBUG, ERROR, FATAL, INFO, OFF, TRACE, WARN

# Set your MinIO credentials
s3_endpoint = 'http://minio:9000'
s3_access_key = 'minio'
s3_secret_key = 'minio123'

# %%
spark = SparkSession.builder\
    .appName(appname)\
    .getOrCreate()
# Out:
# 24/03/18 10:08:20 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
print("=================================================")
spark.sparkContext.setLogLevel(log_level)
print(pyspark.SparkConf().getAll())
# Out:
# =================================================
# [('spark.hadoop.hive.cli.print.header', 'true'), ('spark.hadoop.fs.s3a.connection.ssl.enabled', 'false'), ('spark.app.submitTime', '1710756306212'), ('spark.hadoop.fs.s3a.path.style.access', 'true'), ('spark.sql.catalog.spark_catalog', 'org.apache.iceberg.spark.SparkSessionCatalog'), ('spark.hadoop.fs.s3.endpoint', 'http://minio:9000'), ('spark.hadoop.fs.s3.access.key', 'minio'), ('spark.hadoop.fs.s3.impl', 'org.apache.hadoop.fs.s3a.S3AFileSystem'), ('spark.sql.catalog.iceberg.uri', 'thrift://hive-metastore:9083'), ('spark.sql.catalog.iceberg.s3.endpoint', 'http://minio:9000'), ('spark.sql.catalog.iceberg.s3.path-style-access', 'true'), ('spark.hadoop.fs.s3.path.style.access', 'true'), ('spark.hive.metastore.uris', 'thrift://hive-metastore:9083'), ('spark.master', 'local[*]'), ('spark.app.name', 'BRONZE_iceberg.bronze.iceberg.bronze.bscs_ccontact_all'), ('spark.submit.deployMode', 'client'), ('spark.hadoop.fs.s3a.access.key', 'minio'), ('spark.sql.catalog.iceberg.io-impl', 'org.apache.iceberg.aws.s3.S3FileIO'), ('spark.hadoop.fs.s3.secret.key', 'minio123'), ('spark.sql.extensions', 'org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions'), ('spark.hadoop.fs.s3a.impl', 'org.apache.hadoop.fs.s3a.S3AFileSystem'), ('spark.sql.catalog.iceberg', 'org.apache.iceberg.spark.SparkCatalog'), ('spark.sql.catalogImplementation', 'hive'), ('spark.hadoop.fs.s3.connection.ssl.enabled', 'false'), ('spark.submit.pyFiles', ''), ('spark.sql.catalog.iceberg.warehouse', 's3a://prd-lakehouse/iceberg'), ('spark.hadoop.fs.s3a.endpoint', 'http://minio:9000'), ('spark.hadoop.fs.s3a.secret.key', 'minio123'), ('spark.sql.catalog.iceberg.type', 'hive'), ('spark.ui.showConsoleProgress', 'true'), ('spark.sql.catalog.spark_catalog.type', 'hive')]

# %% [markdown]
# ### Read from the source

# %%
s3 = boto3.client('s3', endpoint_url=s3_endpoint, aws_access_key_id=s3_access_key, aws_secret_access_key=s3_secret_key)

# %%
# List all files in the source directory
file_list = []
paginator = s3.get_paginator('list_objects_v2')

for result in paginator.paginate(Bucket=f"{environment}-{source_bucket}", Prefix=source_folder):
    
    if 'Contents' in result:
        for item in result['Contents']:
            file_list.append(item['Key'])

# %% [markdown]
# #### Data Contract

# %%
df_source_schema = StructType([
                    StructField("tmcode", StringType()),
                    StructField("vscode", StringType()),
                    StructField("vsdate", StringType()),
                    StructField("status", StringType()),
                    StructField("tmind", StringType()),
                    StructField("des", StringType()),
                    StructField("shdes", StringType()),
                    StructField("plcode", StringType()),
                    StructField("plmnname", StringType()),
                    StructField("tmrc", StringType()),
                    StructField("rec_version", StringType()),
                    StructField("apdate", StringType()),
                    StructField("tmglobal", StringType()),
                    StructField("currency", StringType()),
                    StructField("global_iot_ind", StringType()),
                    StructField("dwh_etl_history_fk", StringType()),
                    StructField("flg_processed", StringType()),
                    StructField("flg_error", StringType()),
                    StructField("error_desc", StringType()),
                    StructField("stg_record_load_date", StringType())    
                ])

# %%
num_columns_contract = len(df_source_schema.fields)
print("Number of columns of contract:", num_columns_contract)
# Out:
# Number of columns of contract: 20

# %%
df_source_data = spark.createDataFrame([], schema=df_source_schema)

# %%
# reading files in the source
for file_name in file_list:

    print(f'File in processing: {file_name}')
    
    df = spark.read.format("csv") \
                    .option("header", "true") \
                    .option("delimiter", ",") \
                    .schema(df_source_schema) \
                    .load(f"s3a://{environment}-{source_bucket}/{file_name}")
    
    df.show(5)
    
    if len(df.columns) == num_columns_contract:
        print('No of columns matched')
        df_source_data = df_source_data.union(df)


### Small transformation
df_send_to_bronze = audit_add_column(df_source_data)
# Out:
# File in processing: database/bscs/bscs_mputmtab/20240318/0b150c37-af8d-438b-b91d-fc1aaa299894.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   347|     6|1220227200000|     P| null|ZZ CUG2-C1000 Opt-in|OC210|  null|    null|   0|         59|1219396690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   383|     5|1220227200000|     P| null|CUG2-Enterprise M...|CSFC1|  null|    null|   0|         94|1219396874000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   384|     5|1220227200000|     P| null|CUG2-Optin Enterp...|COSF1|  null|    null|   0|         73|1219396892000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   356|     6|1220227200000|     P| null|    ZZ CUG2-Smart14+|CSM14|  null|    null|   0|        101|1219396935000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   357|     6|1220227200000|     P| null|    ZZ CUG2-Smart24+|CSM24|  null|    null|   0|         98|1219396962000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/0be44c13-0f01-41bc-a804-7956f0a7a8a7.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   366|     7|1251763200000|     P| null|ZZ CUG2-Smart14+ ...|CS14T|  null|    null|   0|         29|1251735144000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   367|     7|1251763200000|     P| null|ZZ CUG2-Smart24+ ...|CS24T|  null|    null|   0|         31|1251735156000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   368|     7|1251763200000|     P| null|ZZ CUG2-Smart36+ ...|CS36T|  null|    null|   0|         27|1251735174000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   369|     7|1251763200000|     P| null|ZZ CUG2-Smart60+ ...|CS60T|  null|    null|   0|         27|1251735185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   283|    17|1251763200000|     P| null|ZZ CUG2-Students-...|STPOI|  null|    null|   0|         55|1251735199000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/0c4f018c-ddc8-417a-a2cb-530b01b87faf.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   366|     7|1251763200000|     P| null|ZZ CUG2-Smart14+ ...|CS14T|  null|    null|   0|         29|1251735144000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   367|     7|1251763200000|     P| null|ZZ CUG2-Smart24+ ...|CS24T|  null|    null|   0|         31|1251735156000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   368|     7|1251763200000|     P| null|ZZ CUG2-Smart36+ ...|CS36T|  null|    null|   0|         27|1251735174000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   369|     7|1251763200000|     P| null|ZZ CUG2-Smart60+ ...|CS60T|  null|    null|   0|         27|1251735185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   283|    17|1251763200000|     P| null|ZZ CUG2-Students-...|STPOI|  null|    null|   0|         55|1251735199000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/0eab9c59-547c-464c-b245-b83bc88e9a57.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   514|     5|1425168000000|     P| null|ZZSmartphone Plan...|S70DD|  null|    null|   0|         15|1425038923000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   364|     1|1207958400000|     P| null|            ZZPOST15|POS15|  null|    null|   0|         66|1207911185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     0|1399939200000|     W| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1276524689000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     1|1207958400000|     P| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1207911193000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     3|1208476800000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1208264192000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/0eb56c82-0dc6-4577-ae11-065a073985f1.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   361|     4|1214870400000|     P| null|ZZ CUG2-Opt-inSma...|COS24|  null|    null|   0|        101|1214212557000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   935|     4|1547078400000|     P| null|         RED L Boost|VIRP4|  null|    null|   0|         19|1546866899000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   937|     3|1547078400000|     P| null|RED L Boost (Device)|VMREG|  null|    null|   0|         16|1546867101000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   358|     4|1214870400000|     P| null|    ZZ CUG2-Smart36+|CSM36|  null|    null|   0|         87|1214212891000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |  1010|     0|1548979200000|     W| null|VML-Project  Atla...|VPAR5|  null|    null| 204|          3|1547213238000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/11f327f6-4c9f-411c-bd41-8ea1dc1d4883.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   740|     0|1480550400000|     W| null|     CUG2-ENT INTERM| EINT|  null|    null|   0|         29|1478696735000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   741|     0|1480550400000|     W| null|CUG2-ENT INTERM T...|EINTt|  null|    null|   0|         30|1478696948000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   742|     0|1498867200000|     W| null|CUG2-ENT INTERM 2...|EINT2|  null|    null|   0|          7|1424795690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   743|     0|1498867200000|     W| null|CUG2-ENT INTERM T...|EINt2|  null|    null|   0|          7|1424874081000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   744|     0|1489708800000|     W| null|  ZZ CUG2-ENT ADVANC| EADV|  null|    null|   0|         29|1478696589000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/13d10e85-8728-4dff-933f-016b6d67f8f2.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   366|     7|1251763200000|     P| null|ZZ CUG2-Smart14+ ...|CS14T|  null|    null|   0|         29|1251735144000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   367|     7|1251763200000|     P| null|ZZ CUG2-Smart24+ ...|CS24T|  null|    null|   0|         31|1251735156000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   368|     7|1251763200000|     P| null|ZZ CUG2-Smart36+ ...|CS36T|  null|    null|   0|         27|1251735174000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   369|     7|1251763200000|     P| null|ZZ CUG2-Smart60+ ...|CS60T|  null|    null|   0|         27|1251735185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   283|    17|1251763200000|     P| null|ZZ CUG2-Students-...|STPOI|  null|    null|   0|         55|1251735199000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/1e38f557-06b4-4ed6-9a15-6b30c9dc45cb.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   740|     0|1480550400000|     W| null|     CUG2-ENT INTERM| EINT|  null|    null|   0|         29|1478696735000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   741|     0|1480550400000|     W| null|CUG2-ENT INTERM T...|EINTt|  null|    null|   0|         30|1478696948000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   742|     0|1498867200000|     W| null|CUG2-ENT INTERM 2...|EINT2|  null|    null|   0|          7|1424795690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   743|     0|1498867200000|     W| null|CUG2-ENT INTERM T...|EINt2|  null|    null|   0|          7|1424874081000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   744|     0|1489708800000|     W| null|  ZZ CUG2-ENT ADVANC| EADV|  null|    null|   0|         29|1478696589000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/1ed2714d-a9c7-45e0-bb11-b5a9c6f5d9bd.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   740|     0|1480550400000|     W| null|     CUG2-ENT INTERM| EINT|  null|    null|   0|         29|1478696735000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   741|     0|1480550400000|     W| null|CUG2-ENT INTERM T...|EINTt|  null|    null|   0|         30|1478696948000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   742|     0|1498867200000|     W| null|CUG2-ENT INTERM 2...|EINT2|  null|    null|   0|          7|1424795690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   743|     0|1498867200000|     W| null|CUG2-ENT INTERM T...|EINt2|  null|    null|   0|          7|1424874081000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   744|     0|1489708800000|     W| null|  ZZ CUG2-ENT ADVANC| EADV|  null|    null|   0|         29|1478696589000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/1f8483ce-62ee-4645-af69-ec7e7d373a12.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   740|     0|1480550400000|     W| null|     CUG2-ENT INTERM| EINT|  null|    null|   0|         29|1478696735000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   741|     0|1480550400000|     W| null|CUG2-ENT INTERM T...|EINTt|  null|    null|   0|         30|1478696948000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   742|     0|1498867200000|     W| null|CUG2-ENT INTERM 2...|EINT2|  null|    null|   0|          7|1424795690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   743|     0|1498867200000|     W| null|CUG2-ENT INTERM T...|EINt2|  null|    null|   0|          7|1424874081000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   744|     0|1489708800000|     W| null|  ZZ CUG2-ENT ADVANC| EADV|  null|    null|   0|         29|1478696589000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/2401a914-4870-49ba-a63f-13fe1c8e839c.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   514|     5|1425168000000|     P| null|ZZSmartphone Plan...|S70DD|  null|    null|   0|         15|1425038923000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   364|     1|1207958400000|     P| null|            ZZPOST15|POS15|  null|    null|   0|         66|1207911185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     0|1399939200000|     W| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1276524689000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     1|1207958400000|     P| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1207911193000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     3|1208476800000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1208264192000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/2bcdf98e-ab19-4316-bf1d-ea381e661017.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   720|     3|1404172800000|     P| null|VODA RED BSC BUS-...|RFBBW|  null|    null|   0|         61|1403696796000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   719|     3|1404172800000|     P| null|VODA RED BSC CON-...|RFBCT|  null|    null|   0|         36|1403696974000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   718|     3|1404172800000|     P| null|VODA RED BSC CON-...|RFBCW|  null|    null|   0|         37|1403696990000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   869|     0|1438387200000|     W| null|VML-Project Atlan...|PACMO|  null|    null|   0|          2|1438170596000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   869|     1|1438387200000|     P| null|VML-Project Atlan...|PACMO|  null|    null|   0|          1|1438170596000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/2c6296a1-41c2-4b71-90f1-e3d103b4a3be.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   514|     5|1425168000000|     P| null|ZZSmartphone Plan...|S70DD|  null|    null|   0|         15|1425038923000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   364|     1|1207958400000|     P| null|            ZZPOST15|POS15|  null|    null|   0|         66|1207911185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     0|1399939200000|     W| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1276524689000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     1|1207958400000|     P| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1207911193000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     3|1208476800000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1208264192000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/2e4eee74-40b6-42d1-b13f-9268ca94c05f.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   740|     0|1480550400000|     W| null|     CUG2-ENT INTERM| EINT|  null|    null|   0|         29|1478696735000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   741|     0|1480550400000|     W| null|CUG2-ENT INTERM T...|EINTt|  null|    null|   0|         30|1478696948000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   742|     0|1498867200000|     W| null|CUG2-ENT INTERM 2...|EINT2|  null|    null|   0|          7|1424795690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   743|     0|1498867200000|     W| null|CUG2-ENT INTERM T...|EINt2|  null|    null|   0|          7|1424874081000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   744|     0|1489708800000|     W| null|  ZZ CUG2-ENT ADVANC| EADV|  null|    null|   0|         29|1478696589000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/2ea5ce02-164e-4d73-a0a3-c07bce6bb3e9.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   514|     5|1425168000000|     P| null|ZZSmartphone Plan...|S70DD|  null|    null|   0|         15|1425038923000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   364|     1|1207958400000|     P| null|            ZZPOST15|POS15|  null|    null|   0|         66|1207911185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     0|1399939200000|     W| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1276524689000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     1|1207958400000|     P| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1207911193000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     3|1208476800000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1208264192000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/3163bb97-4f24-4bed-928b-9996f23f5ae9.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   347|     6|1220227200000|     P| null|ZZ CUG2-C1000 Opt-in|OC210|  null|    null|   0|         59|1219396690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   383|     5|1220227200000|     P| null|CUG2-Enterprise M...|CSFC1|  null|    null|   0|         94|1219396874000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   384|     5|1220227200000|     P| null|CUG2-Optin Enterp...|COSF1|  null|    null|   0|         73|1219396892000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   356|     6|1220227200000|     P| null|    ZZ CUG2-Smart14+|CSM14|  null|    null|   0|        101|1219396935000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   357|     6|1220227200000|     P| null|    ZZ CUG2-Smart24+|CSM24|  null|    null|   0|         98|1219396962000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/31f9832b-251f-42cc-beff-36952c02315b.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   123|    14|1241136000000|     P| null|Own Phone Data Co...|OPDCC|  null|    null|   0|         44|1240859540000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   867|     0|1433116800000|     W| null|VML-Project Atlan...|PABCA|  null|    null|   0|          2|1432892936000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   867|     1|1433116800000|     P| null|VML-Project Atlan...|PABCA|  null|    null|   0|          1|1432892936000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   907|     0|1556668800000|     W| null|  RED Start (DEVICE)|PACDV|  null|    null|   0|         32|1553533556000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   908|     0|1556668800000|     W| null|     RED Value (ECO)|PBCEC|  null|    null|   0|         20|1553533634000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/32fa2226-4407-42fb-a4de-fc896086cd1f.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   366|     7|1251763200000|     P| null|ZZ CUG2-Smart14+ ...|CS14T|  null|    null|   0|         29|1251735144000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   367|     7|1251763200000|     P| null|ZZ CUG2-Smart24+ ...|CS24T|  null|    null|   0|         31|1251735156000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   368|     7|1251763200000|     P| null|ZZ CUG2-Smart36+ ...|CS36T|  null|    null|   0|         27|1251735174000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   369|     7|1251763200000|     P| null|ZZ CUG2-Smart60+ ...|CS60T|  null|    null|   0|         27|1251735185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   283|    17|1251763200000|     P| null|ZZ CUG2-Students-...|STPOI|  null|    null|   0|         55|1251735199000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/38417ca4-991d-40e3-b120-cc9fc718209a.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   740|     0|1480550400000|     W| null|     CUG2-ENT INTERM| EINT|  null|    null|   0|         29|1478696735000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   741|     0|1480550400000|     W| null|CUG2-ENT INTERM T...|EINTt|  null|    null|   0|         30|1478696948000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   742|     0|1498867200000|     W| null|CUG2-ENT INTERM 2...|EINT2|  null|    null|   0|          7|1424795690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   743|     0|1498867200000|     W| null|CUG2-ENT INTERM T...|EINt2|  null|    null|   0|          7|1424874081000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   744|     0|1489708800000|     W| null|  ZZ CUG2-ENT ADVANC| EADV|  null|    null|   0|         29|1478696589000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/387d8135-dca0-496e-bc58-ef5a241ad009.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   361|     4|1214870400000|     P| null|ZZ CUG2-Opt-inSma...|COS24|  null|    null|   0|        101|1214212557000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   935|     4|1547078400000|     P| null|         RED L Boost|VIRP4|  null|    null|   0|         19|1546866899000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   937|     3|1547078400000|     P| null|RED L Boost (Device)|VMREG|  null|    null|   0|         16|1546867101000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   358|     4|1214870400000|     P| null|    ZZ CUG2-Smart36+|CSM36|  null|    null|   0|         87|1214212891000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |  1010|     0|1548979200000|     W| null|VML-Project  Atla...|VPAR5|  null|    null| 204|          3|1547213238000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/3ceb349e-d4a3-45a2-bad1-507d8bacb3ce.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   514|     5|1425168000000|     P| null|ZZSmartphone Plan...|S70DD|  null|    null|   0|         15|1425038923000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   364|     1|1207958400000|     P| null|            ZZPOST15|POS15|  null|    null|   0|         66|1207911185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     0|1399939200000|     W| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1276524689000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     1|1207958400000|     P| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1207911193000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     3|1208476800000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1208264192000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/41249fcc-3328-4386-9921-9708ea8eb43c.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   514|     5|1425168000000|     P| null|ZZSmartphone Plan...|S70DD|  null|    null|   0|         15|1425038923000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   364|     1|1207958400000|     P| null|            ZZPOST15|POS15|  null|    null|   0|         66|1207911185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     0|1399939200000|     W| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1276524689000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     1|1207958400000|     P| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1207911193000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     3|1208476800000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1208264192000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/41500c55-0a72-434f-a7af-835ff70697d4.csv
# ...
# |   365|     1|1207958400000|     P| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1207911193000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     3|1208476800000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1208264192000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/f76e95cd-dafc-4375-918d-c878757abffb.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   366|     7|1251763200000|     P| null|ZZ CUG2-Smart14+ ...|CS14T|  null|    null|   0|         29|1251735144000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   367|     7|1251763200000|     P| null|ZZ CUG2-Smart24+ ...|CS24T|  null|    null|   0|         31|1251735156000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   368|     7|1251763200000|     P| null|ZZ CUG2-Smart36+ ...|CS36T|  null|    null|   0|         27|1251735174000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   369|     7|1251763200000|     P| null|ZZ CUG2-Smart60+ ...|CS60T|  null|    null|   0|         27|1251735185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   283|    17|1251763200000|     P| null|ZZ CUG2-Students-...|STPOI|  null|    null|   0|         55|1251735199000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/f7c8684e-bf9a-4b61-a381-70ef41a3ebd2.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   366|     7|1251763200000|     P| null|ZZ CUG2-Smart14+ ...|CS14T|  null|    null|   0|         29|1251735144000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   367|     7|1251763200000|     P| null|ZZ CUG2-Smart24+ ...|CS24T|  null|    null|   0|         31|1251735156000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   368|     7|1251763200000|     P| null|ZZ CUG2-Smart36+ ...|CS36T|  null|    null|   0|         27|1251735174000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   369|     7|1251763200000|     P| null|ZZ CUG2-Smart60+ ...|CS60T|  null|    null|   0|         27|1251735185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   283|    17|1251763200000|     P| null|ZZ CUG2-Students-...|STPOI|  null|    null|   0|         55|1251735199000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/f7fa570d-4476-4604-b800-c71e62d254d9.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   347|     6|1220227200000|     P| null|ZZ CUG2-C1000 Opt-in|OC210|  null|    null|   0|         59|1219396690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   383|     5|1220227200000|     P| null|CUG2-Enterprise M...|CSFC1|  null|    null|   0|         94|1219396874000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   384|     5|1220227200000|     P| null|CUG2-Optin Enterp...|COSF1|  null|    null|   0|         73|1219396892000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   356|     6|1220227200000|     P| null|    ZZ CUG2-Smart14+|CSM14|  null|    null|   0|        101|1219396935000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   357|     6|1220227200000|     P| null|    ZZ CUG2-Smart24+|CSM24|  null|    null|   0|         98|1219396962000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/f81adef9-679c-463b-91f6-8917cf5e4f82.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   720|     3|1404172800000|     P| null|VODA RED BSC BUS-...|RFBBW|  null|    null|   0|         61|1403696796000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   719|     3|1404172800000|     P| null|VODA RED BSC CON-...|RFBCT|  null|    null|   0|         36|1403696974000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   718|     3|1404172800000|     P| null|VODA RED BSC CON-...|RFBCW|  null|    null|   0|         37|1403696990000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   869|     0|1438387200000|     W| null|VML-Project Atlan...|PACMO|  null|    null|   0|          2|1438170596000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   869|     1|1438387200000|     P| null|VML-Project Atlan...|PACMO|  null|    null|   0|          1|1438170596000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/f8adbe74-ef89-49b1-a7b3-3162be85c4e4.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   740|     0|1480550400000|     W| null|     CUG2-ENT INTERM| EINT|  null|    null|   0|         29|1478696735000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   741|     0|1480550400000|     W| null|CUG2-ENT INTERM T...|EINTt|  null|    null|   0|         30|1478696948000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   742|     0|1498867200000|     W| null|CUG2-ENT INTERM 2...|EINT2|  null|    null|   0|          7|1424795690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   743|     0|1498867200000|     W| null|CUG2-ENT INTERM T...|EINt2|  null|    null|   0|          7|1424874081000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   744|     0|1489708800000|     W| null|  ZZ CUG2-ENT ADVANC| EADV|  null|    null|   0|         29|1478696589000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/fa50bd3a-4147-4cb4-82c4-9e59ec8a1a79.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   514|     5|1425168000000|     P| null|ZZSmartphone Plan...|S70DD|  null|    null|   0|         15|1425038923000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   364|     1|1207958400000|     P| null|            ZZPOST15|POS15|  null|    null|   0|         66|1207911185000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     0|1399939200000|     W| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1276524689000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   365|     1|1207958400000|     P| null|     ZZOpt-in POST15|OPPO1|  null|    null|   0|         60|1207911193000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     3|1208476800000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1208264192000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched
# File in processing: database/bscs/bscs_mputmtab/20240318/ff61598a-06f9-4d38-898d-2cec7b6f9576.csv
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   720|     3|1404172800000|     P| null|VODA RED BSC BUS-...|RFBBW|  null|    null|   0|         61|1403696796000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   719|     3|1404172800000|     P| null|VODA RED BSC CON-...|RFBCT|  null|    null|   0|         36|1403696974000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   718|     3|1404172800000|     P| null|VODA RED BSC CON-...|RFBCW|  null|    null|   0|         37|1403696990000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   869|     0|1438387200000|     W| null|VML-Project Atlan...|PACMO|  null|    null|   0|          2|1438170596000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   869|     1|1438387200000|     P| null|VML-Project Atlan...|PACMO|  null|    null|   0|          1|1438170596000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 5 rows
#
# No of columns matched

# %%
# print("No of lines to load: ", len(df_source_data))
df_source_data.show(10)
# Out:
# 24/03/18 10:10:25 WARN DAGScheduler: Broadcasting large task binary with size 1283.5 KiB
# 24/03/18 10:10:26 WARN DAGScheduler: Broadcasting large task binary with size 1283.5 KiB
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |tmcode|vscode|       vsdate|status|tmind|                 des|shdes|plcode|plmnname|tmrc|rec_version|       apdate|tmglobal|currency|global_iot_ind|dwh_etl_history_fk|flg_processed|flg_error|error_desc|stg_record_load_date|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# |   347|     6|1220227200000|     P| null|ZZ CUG2-C1000 Opt-in|OC210|  null|    null|   0|         59|1219396690000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   383|     5|1220227200000|     P| null|CUG2-Enterprise M...|CSFC1|  null|    null|   0|         94|1219396874000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   384|     5|1220227200000|     P| null|CUG2-Optin Enterp...|COSF1|  null|    null|   0|         73|1219396892000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   356|     6|1220227200000|     P| null|    ZZ CUG2-Smart14+|CSM14|  null|    null|   0|        101|1219396935000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   357|     6|1220227200000|     P| null|    ZZ CUG2-Smart24+|CSM24|  null|    null|   0|         98|1219396962000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   358|     6|1220227200000|     P| null|    ZZ CUG2-Smart36+|CSM36|  null|    null|   0|         87|1219396984000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   359|     6|1220227200000|     P| null|    ZZ CUG2-Smart60+|CSM60|  null|    null|   0|         91|1219396994000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   360|     6|1220227200000|     P| null|ZZ CUG2-Opt-inSma...|COS14|  null|    null|   0|        108|1219397013000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   361|     6|1220227200000|     P| null|ZZ CUG2-Opt-inSma...|COS24|  null|    null|   0|        101|1219397025000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# |   362|     6|1220227200000|     P| null|ZZ CUG2-Opt-inSma...|COS36|  null|    null|   0|         83|1219397036000|       N|     111|             N|              null|         null|     null|      null|       1557417161000|
# +------+------+-------------+------+-----+--------------------+-----+------+--------+----+-----------+-------------+--------+--------+--------------+------------------+-------------+---------+----------+--------------------+
# only showing top 10 rows

# %%
df_source_data.describe()
# Out:
# DataFrame[summary: string, tmcode: string, vscode: string, vsdate: string, status: string, tmind: string, des: string, shdes: string, plcode: string, plmnname: string, tmrc: string, rec_version: string, apdate: string, tmglobal: string, currency: string, global_iot_ind: string, dwh_etl_history_fk: string, flg_processed: string, flg_error: string, error_desc: string, stg_record_load_date: string]

# %% [markdown]
# ### DDL on lakehouse

# %% [markdown]
# #### Data base

# %%
##creating db
sql_db_create = f"""
CREATE DATABASE IF NOT EXISTS {dest_final_db} COMMENT '' LOCATION 's3a://{environment}-{lakehouse_bucket}/{dest_db_catalog}/{dest_db_schema}/'
"""
print(sql_db_create)
spark.sql(sql_db_create)
# Out:
# CREATE DATABASE IF NOT EXISTS iceberg.bronze COMMENT '' LOCATION 's3a://prd-lakehouse/iceberg/bronze/'
# DataFrame[]

# %% [markdown]
# #### Dest table

# %%
sql_ddl_drop_table = f"""
    DROP TABLE IF EXISTS {dest_final_table}
"""

# %%
sql_ddl_create_table = f"""
        create table if not exists {dest_final_table}
        (
        	tmcode string,
			vscode string,
			vsdate string,
			status string,
			tmind string,
			des string,
			shdes string,
			plcode string,
			plmnname string,
			tmrc string,
			rec_version string,
			apdate string,
			tmglobal string,
			currency string,
			global_iot_ind string,
			dwh_etl_history_fk string,
			flg_processed string,
			flg_error string,
			error_desc string,
			stg_record_load_date string
        ) 
        using iceberg
        """

# %% [markdown]
# #### SQL DDL Execution

# %%
## drop table
spark.sql(sql_ddl_drop_table)

## create table
spark.sql(sql_ddl_create_table)
# Out:
# DataFrame[]

# %% [markdown]
# ### Small transformation

# %%
# # some transformations
#     df = df.withColumn("duration", df["duration"].cast("double"))
#     # df = df.withColumn("event_date", to_date(df["record_opening_time"], "yyyyMMddHHmmss"))
#     # to_date(df["record_opening_time"], "yyyyMMddHHmmss")

#     df.withColumn("event_date", from_unixtime(unix_timestamp("record_opening_time", "yyyyMMddHHmmss")))

#     df.select('event_date').show()

# %% [markdown]
# ### Write table

# %%
# wrintint the data on lakehouse
df_send_to_bronze.writeTo(f'{dest_final_table}').append()

# %%
table = spark.table(f'{dest_final_table}')
print(table.printSchema())
print(f"No of Records: {table.count()}")
# Out:
# root
#  |-- tmcode: string (nullable = true)
#  |-- vscode: string (nullable = true)
#  |-- vsdate: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- tmind: string (nullable = true)
#  |-- des: string (nullable = true)
#  |-- shdes: string (nullable = true)
#  |-- plcode: string (nullable = true)
#  |-- plmnname: string (nullable = true)
#  |-- tmrc: string (nullable = true)
#  |-- rec_version: string (nullable = true)
#  |-- apdate: string (nullable = true)
#  |-- tmglobal: string (nullable = true)
#  |-- currency: string (nullable = true)
#  |-- global_iot_ind: string (nullable = true)
#  |-- dwh_etl_history_fk: string (nullable = true)
#  |-- flg_processed: string (nullable = true)
#  |-- flg_error: string (nullable = true)
#  |-- error_desc: string (nullable = true)
#  |-- stg_record_load_date: string (nullable = true)
#
# None
# No of Records: 414030
